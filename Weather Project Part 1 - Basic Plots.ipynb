# %%
from numpy import genfromtxt
import numpy as np
import matplotlib.pyplot as plt 
from datetime import datetime
# %matplotlib inline
csv = np.genfromtxt('weather2.csv', delimiter = "," , skip_header=1)
month = csv[:,1]
day = csv[:,2]
#monthday = np.column_stack((month, day)) IGNORE. Alternative method of obtaining Month/Day as an index.


maxtemp = csv[:,4] #List of dependent variable arrays
mintemp = csv[:,6]
meantemp = csv[:,8]
HeatDegDays = csv[:,10]
CoolDegDays = csv[:,12]
TotalRain= csv[:,14]
TotalSnow= csv[:,16]
TotalPrecip= csv[:,18]
SnowOnGrnd = csv[:,20]
DirMaxGust = csv[:,22]
SpdMaxGust = csv[:,24]
monthday = np.arange('2016-01-01', '2017-01-01', dtype = 'datetime64[D]')
monthday = np.arange(0,366,1)


#MAXIMUM TEMPERATURE
plt.figure(1)
plt.subplot(211)
plt.plot(monthday, maxtemp, 'bo')
plt.xlabel('Date')
plt.ylabel('Max Temp')
plt.title('Max Temp Throughout Year')


plt.subplot(212)
plt.plot(monthday, maxtemp)
plt.xlabel('Date')
plt.ylabel('Max Temp')
plt.legend(['MaxTemp'])

# %%
#MINIMUM TEMPERATURE
plt.figure(1)
plt.subplot(211)
plt.plot(monthday, mintemp, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')

plt.subplot(212)
plt.plot(monthday, mintemp)
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.legend(['MinTemp'])

# %%
#MEAN TEMPERATURE

plt.figure(1)
plt.subplot(211)
plt.plot(monthday, meantemp, 'bo')
plt.xlabel('Date')
plt.ylabel('Mean Temp')
plt.title('Mean Temp Throughout Year')

plt.subplot(212)
plt.plot(monthday, meantemp)
plt.xlabel('Date')
plt.ylabel('Mean Temp')
plt.legend(['MeanTemp'])

# %%
#HEATING DEGREE DAYS THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''
plt.subplot(212)
plt.plot(monthday, HeatDegDays)
plt.xlabel('Date')
plt.ylabel('HeatDegDays')
plt.title('HeatDegDays Throughout Year')
plt.legend(['HeatDegDays'])

# %%
#COOLING DEGREE DAYS THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, CoolDegDays)
plt.xlabel('Date')
plt.ylabel('CoolDegDays') 
plt.title('CoolDegDays Throughout Year')
plt.legend(['CoolDegDays'])

# %%
#TOTAL RAIN THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, TotalRain, '')
plt.xlabel('Date')
plt.ylabel('TotalRain (mm)') 
plt.title('TotalRain Throughout Year')
plt.legend(['TotalRain'])

# %%
#TOTAL SNOW THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, TotalSnow, '')
plt.xlabel('Date')
plt.ylabel('TotalSnow (mm)')
plt.title('TotalSnow Throughout Year')
plt.legend(['TotalSnow'])

# %%
#TOTAL PRECIP THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, TotalPrecip, '')
plt.xlabel('Date')
plt.ylabel('TotalPrecip (mm)') 
plt.title('TotalPrecip Throughout Year')
plt.legend(['TotalPrecip'])

# %%
#TOTAL SNOW ON GROUND THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, 'bo')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, SnowOnGrnd, '')
plt.xlabel('Date')
plt.ylabel('SnowOnGrnd (cm)') 
plt.title('SnowOnGrnd Throughout Year')
plt.legend(['SnowOnGrnd'])

# %%
#DIRECTION OF MAX GUST THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, ')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, DirMaxGust, 'bo')
plt.xlabel('Date')
plt.ylabel('DirMaxGust(Degrees)') 
plt.title('DirMaxGust Throughout Year')
plt.legend(['DirMaxGust'])

# %%
#SPEED OF MAX GUST THROUGHOUT THE YEAR

plt.figure(1)
'''
plt.subplot(211)
plt.plot(monthday, HeatDegDays, ')
plt.xlabel('Date')
plt.ylabel('Min Temp')
plt.title('Min Temp Throughout Year')
'''

plt.subplot(212)
plt.plot(monthday, SpdMaxGust)
plt.xlabel('Date')
plt.ylabel('SpdMaxGust(km/h)') 
plt.title('SpdMaxGust Throughout Year')
plt.legend(['SpdMaxGust'])
